# %%
import networkx as nx
import matplotlib.pyplot as plt
import scipy as sp

# %%
#G = nx.newman_watts_strogatz_graph(6,2,1)
G = nx.watts_strogatz_graph(200,10,0)
print(nx.adjacency_matrix(G))
#G.add_node(2)
#G.add_edge(23,45)
nx.draw(G)
plt.show()
# Out:
#   (0, 1)	1
#   (0, 2)	1
#   (0, 3)	1
#   (0, 4)	1
#   (0, 5)	1
#   (0, 195)	1
#   (0, 196)	1
#   (0, 197)	1
#   (0, 198)	1
#   (0, 199)	1
#   (1, 0)	1
#   (1, 2)	1
#   (1, 3)	1
#   (1, 4)	1
#   (1, 5)	1
#   (1, 6)	1
#   (1, 196)	1
#   (1, 197)	1
#   (1, 198)	1
#   (1, 199)	1
#   (2, 0)	1
#   (2, 1)	1
#   (2, 3)	1
#   (2, 4)	1
#   (2, 5)	1
#   :	:
#   (197, 194)	1
#   (197, 195)	1
#   (197, 196)	1
#   (197, 198)	1
#   (197, 199)	1
#   (198, 0)	1
#   (198, 1)	1
#   (198, 2)	1
#   (198, 3)	1
#   (198, 193)	1
#   (198, 194)	1
#   (198, 195)	1
#   (198, 196)	1
#   (198, 197)	1
#   (198, 199)	1
#   (199, 0)	1
#   (199, 1)	1
#   (199, 2)	1
#   (199, 3)	1
#   (199, 4)	1
#   (199, 194)	1
#   (199, 195)	1
#   (199, 196)	1
#   (199, 197)	1
#   (199, 198)	1
